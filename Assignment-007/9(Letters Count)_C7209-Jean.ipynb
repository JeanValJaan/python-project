# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanValJaan/python-project/blob/main/Assignment-007/9(Letters%20Count)_C7209-Jean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = input("Please enter the sentence to analyze")
sentence_dict = {}
for word in sentence:
    sentence_dict.update({word : sentence.count(word)})
print(sentence_dict)
# Out:
# Please enter the sentence to analyzeCihan Orhan
# {'C': 1, 'i': 1, 'h': 2, 'a': 2, 'n': 2, ' ': 1, 'O': 1, 'r': 1}
