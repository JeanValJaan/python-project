# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanValJaan/python-project/blob/main/assignment007_1_if_else_statements_assignment_Jean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name = input("Please enter your first name").title().strip()
if first_name == "Jean":
    print(f"Hello, {first_name}! The password is w@12")
else:
    print(f"Hello, {first_name}! See you later.")
