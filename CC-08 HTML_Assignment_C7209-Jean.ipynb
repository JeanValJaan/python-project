# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanValJaan/python-project/blob/main/CC-08%20HTML_Assignment_C7209-Jean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<DOCTYPE html>
    <html>
    <head>
        <title>HTML-CCO8</title><h1><i><strong></strong>Clarusway Program<strong></i><br></h1>
     </head>
     <body>
        <table border="4">
            <tr>
                <th rowspan="3"><img src="https://data.whicdn.com/images/305761013/original.jpg" height="180" width="140"></th>
                    <th colspan="3"><br><img height="80" width="200" src="https://clarusway.com/wp-content/uploads/2019/12/cw_sonk%C3%BC%C3%A7%C3%BCk2.png"><br><br><font size='+2'>AWS & DevOps</font><br><br></th>  
        <tr>
        <th colspan='2'>Schedule </th>
            <th rowspan='2'>Topic</th>
        </tr>
        <tr>
            <th>Begin</th>
            <th>End</th>
        </tr>
        <tr>
            <td>Tuesday</td>
            <td>07:00 am</td>
            <td>10:00 am</td>
            <td rowspan='2'>COmputer Fundamentals
                <ul>
                    <li>Hardware</li>
                    <li>OS</li>
                    <li>Storage</li>
                    <li>Data</li>
                </ul>
            </td>
        </tr>
        <tr>
            <td rowspan='3'>Thursday</td>
            <td>07:00 am</td>
            <td>07:50 am</td>
        </tr>
        <tr>
            <td>08:00 am</td>
            <td>08:50 am</td>
            <td rowspan='2'><mark>HTML</mark><br><strike>CSS</strike></td> 
         </tr>
         <tr>
             <td>09:00 pm</td>
             <td>10:00 pm</td>
         </tr>
         <tr>
             <td>Saturday</td>
             <td>11:00 am</td>
             <td>4:00 pm</td>
             <td>Computer Fundamentals</td>
        <tr>
            <td>Sunday</td>
            <td>11:00 am</td>
            <td>4:00 pm</td>
            <td><mark>HTML<br></mark><ol>
                <li>Formatting Elements</li>
                <li>Lists</li>
                <li>Tables</li>
            </ol></td> 
               </tr>
</html>
